# %%
name = input("What is your name?:")
age = int((input("How old are you?:")))
location = input("Where are you now? (As country)")

if name == "":
   print("Probably you forget to write your name")
else:
   pass

if age >= 100
   print("You are too old for our app.")

elif age >= 18:
   pass

else:
   print("Your age is NOT suitable for our app.")

if location == "America":
   print("You are signed up succesfully.")

elif location == "Turkiye":
   print("You are signed up succesfully.")

elif location == "Türkiye":
   print("You are signed up succesfully.")

elif location == "Turkey":
   print("You signed up succesfully. But you don't write your country name correctly. Not Turkey, true options are: Turkiye or Türkiye")

else:
   print("Sorry, your country is not suitable for our app right now.")
