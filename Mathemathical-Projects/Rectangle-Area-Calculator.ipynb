# %%
width = float(input("Enter wight:"))
length = float(input("Enter lenght:"))
area = width * length
print(f"Area: {round (area, 3)}")
# Out:
# Enter wight: 31.11
# Enter lenght: 3.14
# Area: 97.685
